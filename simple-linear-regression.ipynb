# %%
import os

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download('https://www.kaggle.com/datasets/abhishek14398/salary-dataset-simple-linear-regression')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sahityapalacharla
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/abhishek14398/salary-dataset-simple-linear-regression
# ...
# 100%|██████████| 457/457 [00:00<00:00, 664kB/s]

# %%
os.listdir('salary-dataset-simple-linear-regression')
# Out:
# ['Salary_dataset.csv']

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('/content/salary-dataset-simple-linear-regression/Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
len(df)
# Out:
# 30

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.scatter(df[['YearsExperience']],df[['Salary']])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.413333   76004.000000
# std           2.837888   27414.429785
# min           1.200000   37732.000000
# 25%           3.300000   56721.750000
# 50%           4.800000   65238.000000
# 75%           7.800000  100545.750000
# max          10.600000  122392.000000

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
x
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
X_train
# Out:
#     YearsExperience
# 27              9.7
# 11              4.1
# 17              5.4
# 22              8.0
# 5               3.0
# 16              5.2
# 8               3.3
# 14              4.6
# 23              8.3
# 20              6.9
# 1               1.4
# 29             10.6
# 6               3.1
# 4               2.3
# 18              6.0
# 19              6.1
# 9               3.8
# 7               3.3
# 25              9.1
# 3               2.1
# 0               1.2
# 21              7.2
# 15              5.0
# 12              4.1

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([ 40749.96184072, 122700.62295594,  64962.65717022,  63100.14214487,
#        115250.56285456, 107800.50275317])

# %%
y_test
# Out:
# 2      37732.0
# 28    122392.0
# 13     57082.0
# 10     63219.0
# 26    116970.0
# 24    109432.0
# Name: Salary, dtype: float64

# %%
plt.scatter(x=df['YearsExperience'], y=df['Salary'])
plt.plot(X_test,model.predict(X_test),color='red')

# %%
m=model.coef_
m
# Out:
# array([9312.57512673])

# %%
b=model.intercept_
b
# Out:
# 25849.841637955273
